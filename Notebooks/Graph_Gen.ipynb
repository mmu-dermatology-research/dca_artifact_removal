# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
dca_size = ["Small", "Medium", "Large", "Oth"]






binary_dca_baseline_accuracy = [61, 63, 55, 60]
realistic_dca_baseline_accuracy = [60, 64, 60, 58]
#clean_baseline_accuracy = [59, 57, 51, 58]
clean_ns_sr_accuracy = [59, 62, 64, 58]
clean_telea_sr_accuracy = [59, 62, 65, 58]

clean_ns_accuracy = [58, 58, 62, 57]
clean_telea_accuracy = [58, 59, 61, 57]

plt.figure(0)
plt.plot(dca_size, clean_baseline_accuracy, label='Baseline', linestyle= 'dashed')

plt.plot(dca_size, clean_ns_accuracy, label='NS Inpainting')
plt.plot(dca_size, clean_telea_accuracy, label='Telea Inpainting')

plt.plot(dca_size, clean_ns_sr_accuracy, label='NS-SR Inpainting')
plt.plot(dca_size, clean_telea_sr_accuracy, label='Telea-SR Inpainting')

plt.plot(dca_size, binary_dca_baseline_accuracy, label='Binary DCA')
plt.plot(dca_size, realistic_dca_baseline_accuracy, label='Realistic DCA')

plt.title('Accuracy Comparison Between Inpainted Images \n and Models trained on Augmented Images')
plt.xlabel('DCA Size')
plt.ylabel('Accuracy (%)')

plt.legend()
plt.grid()
plt.show()

# %%
clean_baseline_tpr = [86, 91, 99, 90]
binary_dca_baseline_tpr = [90, 94, 96, 83]
realistic_dca_baseline_tpr = [85, 75, 39, 81]

clean_ns_tpr = [87, 90, 81, 87]
clean_telea_tpr = [86, 88, 72, 87]


plt.figure(0)
plt.plot(dca_size, clean_baseline_tpr, label='Baseline', linestyle= 'dashed')
plt.plot(dca_size, clean_ns_tpr, label='NS Inpainting')
plt.plot(dca_size, clean_telea_tpr, label='Telea Inpainting')

plt.plot(dca_size, binary_dca_baseline_tpr, label='Binary DCA')
plt.plot(dca_size, realistic_dca_baseline_tpr, label='Realistic DCA')

plt.legend()
plt.grid()
plt.show()

# %%
clean_baseline_tnr = [32, 24,  1, 26]
binary_dca_baseline_tnr = [33, 31, 13, 36]
realistic_dca_baseline_tnr = [35, 53, 80, 35]

clean_ns_tnr = [30, 26, 43, 27]
clean_telea_tnr = [30, 30, 50, 27]

plt.figure(0)
plt.plot(dca_size, clean_baseline_tnr, label='Baseline', linestyle= 'dashed')
plt.plot(dca_size, clean_ns_tnr, label='NS Inpainting')
plt.plot(dca_size, clean_telea_tnr, label='Telea Inpainting')

plt.plot(dca_size, binary_dca_baseline_tnr, label='Binary DCA')
plt.plot(dca_size, realistic_dca_baseline_tnr, label='Realistic DCA')

plt.legend()
plt.grid()
plt.show()

# %%
fig, axes = plt.subplots(2,1, figsize = (15,15))

axes[0].plot(dca_size, clean_baseline_tpr, label='Baseline', linestyle= 'dashed')
axes[0].plot(dca_size, clean_ns_tpr, label='NS Inpainting')
axes[0].plot(dca_size, clean_telea_tpr, label='Telea Inpainting')
axes[0].plot(dca_size, binary_dca_baseline_tpr, label='Binary DCA')
axes[0].plot(dca_size, realistic_dca_baseline_tpr, label='Realistic DCA')
axes[0].set_title('TPR Comparison Between Inpainted Images \n and Models trained on Augmented Images', size=14)
axes[0].set_xlabel('DCA Size', size=14)
axes[0].set_ylabel('TPR', size=14)
axes[0].legend(loc = 'lower left')
axes[0].grid()


axes[1].plot(dca_size, clean_baseline_tnr, label='Baseline', linestyle= 'dashed')
axes[1].plot(dca_size, clean_ns_tnr, label='NS Inpainting')
axes[1].plot(dca_size, clean_telea_tnr, label='Telea Inpainting')
axes[1].plot(dca_size, binary_dca_baseline_tnr, label='Binary DCA')
axes[1].plot(dca_size, realistic_dca_baseline_tnr, label='Realistic DCA')
axes[1].set_title('TNR Comparison Between Inpainted Images \n and Models trained on Augmented Images', size=14)
axes[1].set_xlabel('DCA Size', size=14)
axes[1].set_ylabel('TNR', size=14)
axes[1].legend(loc = 'lower left')
axes[1].grid()

plt.subplots_adjust(hspace=0.5)

plt.savefig(r"method_comparison_graph.png")

# %%
clean_baseline_f1 = [0.68, 0.68, 0.67, 0.67]
clean_ns_sr_f1 = [0.68, 0.70, 0.70, 0.67]
clean_telea_sr_f1 = [0.68, 0.70, 0.71, 0.67]
binary_dca_baseline_f1 = [0.70, 0.72, 0.68, 0.67]
realistic_dca_baseline_f1 = [0.68, 0.68, 0.50, 0.66]

clean_ns_f1 = [0.67, 0.68, 0.68, 0.67]
clean_telea_f1 = [0.67, 0.68, 0.65, 0.67]



plt.figure(1)
plt.plot(dca_size, clean_baseline_f1, label='Baseline', linestyle= 'dashed')

plt.plot(dca_size, clean_ns_f1, label='NS Inpainting')
plt.plot(dca_size, clean_telea_f1, label='Telea Inpainting')

plt.plot(dca_size, clean_ns_sr_f1, label='NS-SR Inpainting')
plt.plot(dca_size, clean_telea_sr_f1, label='Telea-SR Inpainting')

plt.plot(dca_size, binary_dca_baseline_f1, label='Binary DCA')
plt.plot(dca_size, realistic_dca_baseline_f1, label='Realistic DCA')

plt.title('F1 Score Comparison Between Inpainted Images \n and Models trained on Augmented Images')
plt.xlabel('DCA Size')
plt.ylabel('F1 Score')

plt.legend()
plt.grid()
plt.show()

# %%
fig, axes = plt.subplots(2,1, figsize = (15,15))

axes[0].plot(dca_size, clean_baseline_accuracy, label='Baseline', linestyle= 'dashed')
axes[0].plot(dca_size, clean_ns_accuracy, label='NS Inpainting')
axes[0].plot(dca_size, clean_telea_accuracy, label='Telea Inpainting')
axes[0].plot(dca_size, clean_ns_sr_accuracy, label='NS-SR Inpainting')
axes[0].plot(dca_size, clean_telea_sr_accuracy, label='Telea-SR Inpainting')
axes[0].plot(dca_size, binary_dca_baseline_accuracy, label='Binary DCA')
axes[0].plot(dca_size, realistic_dca_baseline_accuracy, label='Realistic DCA')
axes[0].set_title('Accuracy Comparison Between Inpainted Images \n and Models trained on Augmented Images', size=14)
axes[0].set_xlabel('DCA Size', size=14)
axes[0].set_ylabel('Accuracy (%)', size=14)
axes[0].legend(loc = 'lower left')
axes[0].grid()


axes[1].plot(dca_size, clean_baseline_f1, label='Baseline', linestyle= 'dashed')
axes[1].plot(dca_size, clean_ns_f1, label='NS Inpainting')
axes[1].plot(dca_size, clean_telea_f1, label='Telea Inpainting')
axes[1].plot(dca_size, clean_ns_sr_f1, label='NS-SR Inpainting')
axes[1].plot(dca_size, clean_telea_sr_f1, label='Telea-SR Inpainting')
axes[1].plot(dca_size, binary_dca_baseline_f1, label='Binary DCA')
axes[1].plot(dca_size, realistic_dca_baseline_f1, label='Realistic DCA')
axes[1].set_title('F1 Score Comparison Between Inpainted Images \n and Models trained on Augmented Images', size=14)
axes[1].set_xlabel('DCA Size', size=14)
axes[1].set_ylabel('F1 Score', size=14)
axes[1].legend()
axes[1].grid()

plt.subplots_adjust(hspace=0.5)

plt.savefig(r"method_comparison_graph.png")

# %%
from PIL import Image

# %%
clean = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/clean/mel/ISIC2019_0066792_mel.jpg")
binary = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/dca_binary/mel/ISIC2019_0066792_mel.jpg")
realistic = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/dca_realistic/mel/ISIC2019_0066792_mel.jpg")
orig = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/base/medium/oth/ISIC2019_0053889_oth.jpg")

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))
axes[0].imshow(orig);axes[0].set_title("Clean", fontsize=16)
axes[1].imshow(binary);axes[1].set_title("Binary DCA", fontsize=16)
axes[2].imshow(realistic);axes[2].set_title("Realistic DCA", fontsize=16)
for ax in axes:
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])

#fig.savefig(r"/home/sam/Repositories/temp/artifact_project/images/temp_fig.jpg")

# %%
realistic_crop = np.asarray(realistic)[25:60,25:60]
plt.imshow(realistic_crop)

# %%
binary_crop = np.asarray(binary)[25:60,25:60]
plt.imshow(binary_crop)

# %%
orig_crop = np.asarray(orig)[25:60,25:60]
plt.imshow(orig_crop)

# %%
fig, axes = plt.subplots(1, 3, figsize=(15,5))
axes[0].imshow(orig_crop);axes[0].set_title("True DCA", fontsize=16)
axes[1].imshow(binary_crop);axes[1].set_title("Binary DCA", fontsize=16)
axes[2].imshow(realistic_crop);axes[2].set_title("Realistic DCA", fontsize=16)
for ax in axes:
    ax.set_yticklabels([])
    ax.set_xticklabels([])
    ax.set_xticks([])
    ax.set_yticks([])
#fig.savefig(r"/home/sam/Repositories/temp/artifact_project/images/border_comparison.jpg")

# %% [markdown]
# ## Dataset Comparison

# %%
clean_1 = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/clean/mel/ISIC2017_0000176_mel.jpg")
clean_2 = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/clean/mel/ISIC2019_0025128_mel.jpg")
clean_3 = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/clean/mel/ISIC2019_0024898_mel.jpg")
clean_4 = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/train/clean/mel/ISIC2019_0027021_mel.jpg")
small_dca = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/base/small/mel/ISIC2019_0059697_mel.jpg")
medium_dca = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/base/medium/mel/ISIC2019_0073115_mel.jpg")
large_dca = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/base/large/mel/ISIC2019_0073075_mel.jpg")
oth_dca = Image.open("/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/base/oth/mel/ISIC2019_0000307_mel.jpg")

# %%
plt.imshow(oth_dca)

# %%
fig, axes = plt.subplots(2, 4, figsize=(15,7))
axes[0][0].imshow(clean_1);axes[0][0].set_title("Clean (Train/Val)", fontsize = 16)
axes[0][1].imshow(clean_2);axes[0][1].set_title("Clean (Train/Val)", fontsize = 16)
axes[0][2].imshow(clean_3);axes[0][2].set_title("Clean (Train/Val)", fontsize = 16)
axes[0][3].imshow(clean_4);axes[0][3].set_title("Clean (Train/Val)", fontsize = 16)

axes[1][0].imshow(small_dca);axes[1][0].set_title("Small DCA (Test)", fontsize = 16)
axes[1][1].imshow(medium_dca);axes[1][1].set_title("Medium DCA (Test)", fontsize = 16)
axes[1][2].imshow(large_dca);axes[1][2].set_title("Large DCA (Test)", fontsize = 16)
axes[1][3].imshow(oth_dca);axes[1][3].set_title("Oth DCA (Test)", fontsize = 16)

for row in axes:
    for ax in row:
        ax.set_yticklabels([])
        ax.set_xticklabels([])
        ax.set_xticks([])
        ax.set_yticks([])
fig.savefig(r"/home/sam/Repositories/temp/artifact_project/images/subset_comparison.jpg")
