# %% [markdown]
# # Grad-CAM Inscribed DCA Notebook
#
# This notebook is used to prove that the baseline network is using the DCA to predict the class.
#
# ## Imports

# %%
# append custom system path for custom modules folder in directory if not already
import sys
if  '../../Modules' not in sys.path:
    sys.path.insert(0, '../../Modules')
import gradcam
import tensorflow as tf
import tensorflow.keras as keras
import cv2
import matplotlib.pyplot as plt
import numpy as np
from PIL import Image
import run_gradcam_experiment
import os
# Out:
# 2022-08-09 17:03:14.922037: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-08-09 17:03:14.922049: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
#image_folder = "base/small/mel/"

path_to_model = r"/home/sam/Repositories/temp/artifact_project/models/clean/InceptionResNetV2/SGD/64/InceptionResNetV2_batchSize_0_opt_SGD_model.29.h5"
path_to_image_directory = r"/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/test/"
#path_to_image_directory = r"/home/sam/Repositories/temp/artifact_project/images/"
conv_layer_name = "conv_7b_ac"

save_path = r"/home/sam/Repositories/temp/artifact_project/images/balanced_dca_split/data/extracted_heatmaps/clean/"

model = run_gradcam_experiment.load_model_custom(path_to_model)

# %%
image_paths = [
              #"base/large/mel/",
              #"base/large/oth/",
              #"base/medium/mel/",
              #"base/medium/oth/",
              #"base/small/mel/",
              #"base/small/oth/",
              #"base/oth/mel/",
              #"base/oth/oth/",
              #"ns_sr/large/mel/",
              #"ns_sr/large/oth/",
              #"ns_sr/medium/mel/",
              #"ns_sr/medium/oth/",
              #"ns_sr/small/mel/",
              #"ns_sr/small/oth/",
              #"ns_sr/oth/mel/",
              #"ns_sr/oth/oth/",
              #"telea_sr/large/mel/",
              #"telea_sr/large/oth/",
              #"telea_sr/medium/mel/",
              #"telea_sr/medium/oth/",
              #"telea_sr/small/mel/",
              #"telea_sr/small/oth/",
              #"telea_sr/oth/mel/",
              #"telea_sr/oth/oth/",
              "ns/large/mel/",
              "ns/large/oth/",
              "ns/medium/mel/",
              "ns/medium/oth/",
              "ns/small/mel/",
              "ns/small/oth/",
              "ns/oth/mel/",
              "ns/oth/oth/",
              "telea/large/mel/",
              "telea/large/oth/",
              "telea/medium/mel/",
              "telea/medium/oth/",
              "telea/small/mel/",
              "telea/small/oth/",
              "telea/oth/mel/",
              "telea/oth/oth/",
              ]
for path in image_paths:
    image_dir = path_to_image_directory + path
    for img in os.listdir(image_dir):
        (heatmap, output) = run_gradcam_experiment.run_gradcam_experiment2(model, image_dir+img, conv_layer_name)
        Image.fromarray(heatmap).save(save_path + path + img)
# Out:
# ...
# 1/1 [==============================] - 0s 42ms/step
# ...
# ...
# 1/1 [==============================] - 0s 41ms/step
